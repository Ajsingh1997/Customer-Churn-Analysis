# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\ajayr\Downloads\Customer-Churn-analysis-main\Customer-Churn-analysis-main\Customer Churn.csv")

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
pd.isnull(df)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
pd.isnull(df).sum().sum()
# Out:
# 0

# %%
df['TotalCharges']=df['TotalCharges'].replace(" ","0")
df['TotalCharges']=df['TotalCharges'].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df["customerID"].duplicated().sum()
# Out:
# 0

# %%
def conv(value):
    if value ==1:
        return "Yes"
    else:
        return "No"
df['SeniorCitizen'] = df['SeniorCitizen'].apply(conv)

# %%
df.head(10)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
# 5  9305-CDSKC  Female            No      No         No       8          Yes
# 6  1452-KIOVK    Male            No      No        Yes      22          Yes
# 7  6713-OKOMC  Female            No      No         No      10           No
# 8  7892-POOKP  Female            No     Yes         No      28          Yes
# 9  6388-TABGU    Male            No      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
ax = sns.countplot(x ='Churn', data = df)

for bars in ax.containers:   # or we can do :- ax.bar_label(ax.containers[0]) plt.show()
    ax.bar_label(bars)

# %%
gb=df.groupby('Churn').agg({'Churn':'count'})
plt.pie(gb['Churn'],labels=gb.index, autopct='%1.2f%%')
sns.set(rc={'figure.figsize':(3,4)})# plt.figure(figsize=(3,4)
plt.title('Percetage Of Churned Customeres', fontsize=10)
plt.show()

# %% [markdown]
# # From the above chart we can conclude that the 26.54% of our customers have churned out

# %%
ax= sns.countplot(x='gender', data = df, hue= 'Churn',palette={'Yes': 'red', 'No': 'green'})
sns.set(rc={'figure.figsize':(18,8)})
for bars in ax.containers:
    ax.bar_label(bars)
    
plt.title('Churn By Gender')
# Out:
# Text(0.5, 1.0, 'Churn By Gender')

# %% [markdown]
# # Above count plot shows Churn based on Gender

# %%
#Calculate the percentage of churn for each gender category
churn_counts = df.groupby('gender')['Churn'].value_counts(normalize=True).unstack() * 100

# Create a stacked bar chart
ax = churn_counts.plot(kind='bar', stacked=True, figsize=(12, 6), 
                       color={'Yes': 'red', 'No': 'green'})

# Add percentage labels
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.1f%%', label_type='center', color='white', fontsize=12)

# Customize labels and title
plt.xlabel("Gender", fontsize=14)
plt.ylabel("Percentage", fontsize=14)
plt.xticks(rotation=0)
plt.title("Churn Percentage by Gender", fontsize=16)
plt.legend(title="Churn", labels=["No (Stayed)", "Yes (Churned)"], loc="upper right")

# Show plot
plt.show()

# %%
ax= sns.countplot(x='SeniorCitizen', data = df, hue= 'Churn',palette={'Yes': 'red', 'No': 'green'})
sns.set(rc={'figure.figsize':(18,8)})
for bars in ax.containers:
    ax.bar_label(bars)
    
plt.title('Churn By SeniorCitizen')
# Out:
# Text(0.5, 1.0, 'Churn By SeniorCitizen')

# %%
churn_counts = df.groupby('SeniorCitizen')['Churn'].value_counts(normalize=True).unstack() * 100

# Create a stacked bar chart
ax = churn_counts.plot(kind='bar',stacked=True,  figsize=(10, 4), 
                       color={'Yes': 'red', 'No': 'green'})

# Add percentage labels
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.1f%%', label_type='center', color='white', fontsize=12)

# Customize labels and title
plt.xlabel("Senior Citizen", fontsize=14)
plt.ylabel("Percentage", fontsize=14)
plt.xticks( ticks=[0, 1], labels=['Non-Senior Citizen', 'Senior Citizen'],rotation=0)
plt.title("Churn Percentage by Senior Citizen Status", fontsize=16)
plt.legend(title="Churn", labels=["No (Stayed)", "Yes (Churned)"], loc="upper right")

# Show plot
plt.show()

# %% [markdown]
# #Comparative a greater percentage of people in senior citizen category have churned out

# %%
ax= sns.histplot(x='tenure', data = df, hue= 'Churn',palette={'Yes': 'blue', 'No': 'yellow'})
sns.set(rc={'figure.figsize':(10,15)})
for bars in ax.containers:
    ax.bar_label(bars)
    
plt.title('Churn By tenure')
# Out:
# C:\Users\ajayr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ajayr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ajayr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# #People who have used our services for a long time have stayed and people who have used our services for a short term have been churned

# %%
ax= sns.countplot(x='Contract', data = df, hue= 'Churn',palette={'Yes': 'blue', 'No': 'yellow'})
sns.set(rc={'figure.figsize':(18,8)})
for bars in ax.containers:
    ax.bar_label(bars)
    
plt.title('Churn of customer by Contract')
# Out:
# Text(0.5, 1.0, 'Churn of customer by Contract')

# %% [markdown]
# #People have month to month contract have churn earlier as compare to those people who have the contract of One-year or Two-year

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
columns = ['PhoneService', 'MultipleLines', 'InternetService',
           'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
           'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
           'PaperlessBilling', 'PaymentMethod']

# Set up the subplot grid
rows, cols = 4, 3  # Adjust based on the number of plots (4x3 grid for 12 plots)
fig, axes = plt.subplots(rows, cols, figsize=(18, 16))  # Define the figure size

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through the columns and create a countplot for each
for i, col in enumerate(columns):
    sns.countplot(x=df[col], ax=axes[i], palette={'Yes':'yellow', 'No':'Blue'}, hue=df['Churn'])
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for readability

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# #The visualizations show that customers without additional services like Online Security, Tech Support, and Backup tend to churn more. Fiber optic users, month-to-month contracts, and paperless billing customers have the highest churn rates. To improve retention, strategies should focus on long-term contracts, bundled services, and enhanced customer support.
#
# #Customers with month-to-month contracts, electronic check payments, and paperless billing have higher churn rates. Those with long-term contracts (one or two years) and traditional payment methods tend to stay. Providing incentives for long-term commitments and reducing friction in digital billing could help reduce churn.

# %%
ax= sns.countplot(x='PaymentMethod', data = df, hue= 'Churn',palette={'Yes': 'yellow', 'No': 'blue'})
sns.set(rc={'figure.figsize':(6,4)})
for bars in ax.containers:
    ax.bar_label(bars)
plt.xticks(rotation=45)
    
plt.title('Customer Churn by PaymentMethod')
# Out:
# Text(0.5, 1.0, 'Customer Churn by PaymentMethod')

# %%
# Above countplot shows that most of the cutomers churn by Electronic check Payment method
